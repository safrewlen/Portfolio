# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import locale
locale.setlocale(locale.LC_NUMERIC, '')
# Out:
# 'English_United States.1252'

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_6k\rat_6k_baseline_1.csv', engine='python', sep=';', index_col=0)
avg = df[35:].copy()
df = df[:34]
bl1_rat_6k = df.drop(df.index[[0, 1, 15, 16]]).reset_index(drop=True).applymap(locale.atof)
# bl1_rat_6k
# avg
# print(bl1_rat_6k.count())
print(bl1_rat_6k.shape[0])
bl1_rat_6k.head()
# Out:
# 30
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    35110000.0  109400000.0   2789.0     4129.0     1340.0    1425.0
# 1    32880000.0   99930000.0   2548.0     3927.0     1378.0    1449.0
# 2    32080000.0   97130000.0   2477.0     3852.0     1375.0    1434.0
# 3    33040000.0   96800000.0   2485.0     3765.0     1281.0    1356.0
# 4    30970000.0   96760000.0   2451.0     3731.0     1279.0    1346.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    3968.0       1661.0       4889.0        9664.0    ...
# 1    3771.0       1651.0       4096.0        9524.0    ...
# 2    3774.0       1647.0       4855.0        9483.0    ...
# 3    3609.0       1656.0       5040.0        9501.0    ...
# 4    3668.0       1650.0       4281.0        9538.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0         260700000.0          11800000.0             -4575.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_6k\rat_6k_baseline_saline.csv', engine='python', sep=';', index_col=0)
avg = df[32:].copy()
df = df[:31]
bls_rat_6k = df.reset_index(drop=True).applymap(locale.atof)
# bls_rat_6k
# avg
print(bls_rat_6k.shape[0])
bls_rat_6k.count()
# bls_rat_6k.head()
# Out:
# 31
# SW (mmHg*µL)          31
# CO (µL/min)           31
# SV (µL)               31
# Vmax (µL)             31
# Vmin (µL)             31
# Ves (µL)              31
# Ved (µL)              31
# Pmax (mmHg)           31
# Pmin (mmHg)           31
# Pmean (mmHg)          31
# Pdev (mmHg)           31
# Pes (mmHg)            31
# Ped (mmHg)            31
# HR (bpm)              31
# EF (%)                31
# Ea (mmHg/µL)          31
# PowMax (mmHg*µL/s)    31
# dP/dt max (mmHg/s)    31
# dP/dt min (mmHg/s)    31
# dV/dt max (µL/s)      31
# dV/dt min (µL/s)      31
# P@dV/dt max (mmHg)    31
# P@dP/dt max (mmHg)    31
# V@dP/dt max (µL)      31
# V@dP/dt min (µL)      31
# Tau (ms)              31
# dtype: int64

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_7k\rat_7k_baseline_1.csv', engine='python', sep=';', index_col=0)
avg = df[26:].copy()
df = df[:25]
bl1_rat_7k = df.reset_index(drop=True).applymap(locale.atof)
# df
# avg
print(bl1_rat_7k.shape[0])
# bl1_rat_7k
bl1_rat_7k.head()
# Out:
# 25
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    37400000.0  121500000.0   3340.0     4962.0     1622.0    1639.0
# 1    39750000.0  121300000.0   3335.0     5056.0     1721.0    1735.0
# 2    42070000.0  129100000.0   3550.0     5121.0     1571.0    1609.0
# 3    37860000.0  120600000.0   3356.0     4928.0     1572.0    1589.0
# 4    38490000.0  123700000.0   3401.0     5105.0     1704.0    1718.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    4566.0       1408.0       4172.0        7485.0    ...
# 1    4976.0       1391.0       1081.0        7343.0    ...
# 2    5081.0       1403.0       2620.0        7486.0    ...
# 3    4634.0       1415.0       1607.0        7489.0    ...
# 4    4945.0       1409.0       4514.0        7453.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0         165800000.0          11000000.0             -8817.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_7k\rat_7k_baseline_2.csv', engine='python', sep=';', index_col=0)
avg = df[25:].copy()
df = df[:24]
bl2_rat_7k = df.reset_index(drop=True).applymap(locale.atof)
# df
# bl2_rat_7k
# avg
print(bl2_rat_7k.shape[0])
bl2_rat_7k.head()
# Out:
# 24
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    57260000.0  163900000.0   4425.0     5983.0     1558.0    1573.0
# 1    34630000.0  153300000.0   4012.0     5634.0     1622.0    1635.0
# 2    56770000.0  154700000.0   4177.0     5827.0     1649.0    1680.0
# 3    39390000.0  141300000.0   3674.0     5216.0     1542.0    1556.0
# 4    47770000.0  153300000.0   4139.0     5958.0     1819.0    1837.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    5923.0       1546.0       2264.0        8284.0    ...
# 1    4401.0       1535.0       6840.0        8497.0    ...
# 2    5675.0       1534.0       8071.0        8161.0    ...
# 3    4623.0       1544.0       7592.0        8594.0    ...
# 4    5282.0       1518.0       3010.0        8075.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0         128400000.0          11790000.0             -8933.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_7k\rat_7k_baseline_saline_2.csv', engine='python', sep=';', index_col=0)
avg = df[36:].copy()
df = df[:35]
bls2_rat_7k = df.reset_index(drop=True).applymap(locale.atof)
# df
# bls2_rat_7k
# avg
print(bls2_rat_7k.shape[0])
bls2_rat_7k.head()
# Out:
# 35
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    26850000.0  104900000.0   2883.0     4778.0     1895.0    1905.0
# 1    36530000.0  105700000.0   2924.0     4886.0     1962.0    1983.0
# 2    38580000.0  110400000.0   3056.0     4875.0     1819.0    1847.0
# 3    29940000.0  100000000.0   2768.0     4548.0     1780.0    1802.0
# 4    32130000.0  102100000.0   2824.0     4803.0     1979.0    1995.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    3964.0       1466.0      -3420.0        7309.0    ...
# 1    4799.0       1448.0      -9576.0        7077.0    ...
# 2    4875.0       1448.0       1922.0        7115.0    ...
# 3    4081.0       1452.0       6908.0        7173.0    ...
# 4    4570.0       1436.0      -2326.0        7044.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0         461700000.0          12170000.0             -9364.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_10k\rat_10k_baseline_4.csv', engine='python', sep=';', index_col=0)
avg = df[36:].copy()
df = df[:35]
bl4_rat_10k = df.reset_index(drop=True).applymap(locale.atof)
# df
# bl4_rat_10k
# avg
print(bl4_rat_10k.shape[0])
bl4_rat_10k.head()
# Out:
# 35
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    32790000.0  100600000.0   2816.0     5914.0     3098.0    3145.0
# 1    31650000.0  135500000.0   3772.0     6336.0     2564.0    3059.0
# 2    38490000.0  160000000.0   4426.0     6998.0     2572.0    2869.0
# 3    46950000.0  143300000.0   3964.0     7106.0     3141.0    3226.0
# 4    36110000.0  113700000.0   3182.0     6591.0     3409.0    3428.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    5836.0       1239.0      -3023.0        5274.0    ...
# 1    5459.0       1223.0      -7729.0        5346.0    ...
# 2    6329.0       1259.0       9302.0        5758.0    ...
# 3    7038.0       1287.0      -2155.0        5774.0    ...
# 4    6552.0       1261.0      -2914.0        5468.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0         158400000.0          11310000.0         -12140000.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_10k\rat_10k_baseline_saline_1.csv', engine='python', sep=';', index_col=0)
avg = df[38:].copy()
df = df[:37]
bls1_rat_10k = df.reset_index(drop=True).applymap(locale.atof)
# df
# bls1_rat_10k
# avg
print(bls1_rat_10k.shape[0])
bls1_rat_10k.head()
# Out:
# 37
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    29720000.0   97680000.0   2589.0     5170.0     2582.0    2659.0
# 1    28990000.0   89630000.0   2390.0     5300.0     2910.0    2934.0
# 2    25940000.0   79740000.0   2153.0     4986.0     2833.0    2861.0
# 3    26400000.0  101900000.0   2717.0     5043.0     2326.0    2513.0
# 4    29940000.0   99100000.0   2643.0     5280.0     2637.0    2682.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    5049.0       1356.0       7387.0        6581.0    ...
# 1    5199.0       1352.0      -3680.0        6327.0    ...
# 2    4912.0       1325.0      -3926.0        6012.0    ...
# 3    4501.0       1332.0      -1252.0        6230.0    ...
# 4    5066.0       1353.0       6772.0        6459.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0         120200000.0          13970000.0         -11610000.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_13\rat_13_baseline_2.csv', engine='python', sep=';', index_col=0)
avg = df[32:].copy()
df = df[:31]
bl2_rat_13 = df.reset_index(drop=True).applymap(locale.atof)
# df
# bl2_rat_13
# avg
print(bl2_rat_13.shape[0])
bl2_rat_13.head()
# Out:
# 31
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0        5184.0   37870000.0   2020.0     2443.0     4232.0    7688.0
# 1        4401.0   38620000.0   2079.0     2540.0     4608.0    9394.0
# 2        5405.0   41780000.0   2214.0     2648.0     4336.0    8271.0
# 3        3893.0   36910000.0   1932.0     2412.0     4801.0    9971.0
# 4        5081.0   39310000.0   2077.0     2511.0     4338.0    8411.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    1177.0       7437.0       1461.0        3304.0    ...
# 1    1110.0       7338.0       1363.0        3221.0    ...
# 2    1128.0       7461.0       1470.0        3339.0    ...
# 3    1102.0       7257.0       1364.0        3227.0    ...
# 4    1064.0       7361.0       1500.0        3329.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0         265600000.0              1888.0             -1115.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_13\rat_13_baseline_saline_2.csv', engine='python', sep=';', index_col=0)
avg = df[7:].copy()
df = df[:6]
bls2_rat_13 = df.reset_index(drop=True).applymap(locale.atof)
# df
# bl2_rat_13
# avg
print(bls2_rat_13.shape[0])
bls2_rat_13.head()
# Out:
# 6
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    15200000.0   86890000.0   4605.0     6301.0     1696.0    2628.0
# 1    15450000.0   78450000.0   4171.0     5849.0     1678.0    2478.0
# 2    16400000.0   77020000.0   4069.0     5768.0     1699.0    2282.0
# 3    14330000.0   73590000.0   3949.0     5706.0     1756.0    2339.0
# 4    14460000.0   80460000.0   4331.0     6034.0     1702.0    2383.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    3981.0       6228.0       5049.0        2427.0    ...
# 1    3759.0       6170.0       5104.0        2392.0    ...
# 2    3494.0       6186.0       5117.0        2410.0    ...
# 3    3510.0       6163.0       5145.0        2371.0    ...
# 4    3613.0       6202.0       5111.0        2385.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0         549400000.0              1799.0             -1272.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_15\rat_15_baseline.csv', engine='python', sep=';', index_col=0)
avg = df[13:].copy()
df = df[:12]
bl_rat_15 = df.reset_index(drop=True).applymap(locale.atof)
# df
# avg
print(bl_rat_15.shape[0])
bl_rat_15.head()
# Out:
# 12
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    32230000.0  112400000.0   3128.0     6534.0     3406.0    3504.0
# 1    34860000.0  104700000.0   3279.0     6758.0     3479.0    3523.0
# 2    33940000.0  100300000.0   3076.0     6519.0     3443.0    3551.0
# 3    29490000.0   83880000.0   2726.0     6447.0     3721.0    3773.0
# 4    28140000.0   80580000.0   2552.0     6175.0     3623.0    3730.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    6300.0       1277.0       2689.0        7571.0    ...
# 1    5911.0       1296.0       2524.0        7255.0    ...
# 2    5993.0       1312.0       1156.0        7486.0    ...
# 3    5536.0       1286.0      -1163.0        6801.0    ...
# 4    5602.0       1271.0      -2011.0        6801.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0         277100000.0              7389.0             -6821.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_15\rat_15_baseline_saline.csv', engine='python', sep=';', index_col=0)
avg = df[22:].copy()
df = df[:21]
bls_rat_15 = df.reset_index(drop=True).applymap(locale.atof)
# df
# avg
print(bls_rat_15.shape[0])
bls_rat_15.head()
# Out:
# 21
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    32210000.0   93040000.0   2900.0     7200.0     4300.0    4493.0
# 1    32890000.0   97860000.0   3050.0     7220.0     4170.0    4268.0
# 2    32370000.0   95340000.0   3019.0     7212.0     4192.0    4328.0
# 3    30740000.0   87410000.0   2724.0     6818.0     4094.0    4281.0
# 4    32350000.0   94790000.0   3002.0     7292.0     4290.0    4563.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    5582.0       1313.0       6055.0        8129.0    ...
# 1    5635.0       1317.0       5863.0        8073.0    ...
# 2    5335.0       1292.0       2073.0        7723.0    ...
# 3    5301.0       1280.0       1478.0        7698.0    ...
# 4    5277.0       1282.0       1868.0        7725.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0          94810000.0              7389.0             -5288.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_16\rat_16_baseline_4_revsion.csv', engine='python', sep=';', index_col=0)
avg = df[19:].copy()
df = df[:18]
bl4r_rat_16 = df.drop(df.index[[3, 6, 12]]).reset_index(drop=True).applymap(locale.atof)
# df
# bls4r_rat_16
# avg
print(bl4r_rat_16.shape[0])
bl4r_rat_16.head()
# Out:
# 15
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    24320000.0   98240000.0   3848.0     7064.0     3216.0    3254.0
# 1    50730000.0  122600000.0   4882.0     7749.0     2868.0    3134.0
# 2    22290000.0   77570000.0   3051.0     6173.0     3121.0    3190.0
# 3    37550000.0   99030000.0   3928.0     7338.0     3410.0    3472.0
# 4    44650000.0  107100000.0   4264.0     7150.0     2886.0    3059.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    5153.0       8366.0      -3406.0        2600.0    ...
# 1    7106.0       8797.0      -4075.0        2812.0    ...
# 2    4800.0       7707.0      -4111.0        1849.0    ...
# 3    6620.0       7739.0      -4149.0        1997.0    ...
# 4    6472.0       8681.0      -3660.0        2733.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0          82030000.0              4094.0             -3711.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_16\rat_16_baseline_saline_2_revsion.csv', engine='python', sep=';', index_col=0)
avg = df[10:].copy()
df = df[:9]
bls2r_rat_16 = df.reset_index(drop=True).applymap(locale.atof)
# df
# bls2r_rat_16
# avg
print(bls2r_rat_16.shape[0])
bls2r_rat_16.head()
# Out:
# 9
#    SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 0    24110000.0   93700000.0   3873.0     5416.0     1543.0    1569.0
# 1    36310000.0  132100000.0   5418.0     6531.0     1114.0    1129.0
# 2    23310000.0  101800000.0   4190.0     5658.0     1469.0    1492.0
# 3    36590000.0  138900000.0   5720.0     6939.0     1219.0    1233.0
# 4    24540000.0  109800000.0   4540.0     6071.0     1531.0    1551.0
#
#    Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 0    4380.0       7303.0      -2293.0        3188.0    ...
# 1    5508.0       7722.0      -2162.0        3492.0    ...
# 2    4379.0       7213.0      -2441.0        3139.0    ...
# 3    5747.0       7604.0      -2397.0        3392.0    ...
# 4    4428.0       7168.0      -2698.0        3095.0    ...
#
#    PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 0          48450000.0              2222.0             -3037.0
# ...

# %%
plt.figure(figsize=(8,8))
reshape = pd.concat([bl1_rat_6k['SW (mmHg*µL)'], bls_rat_6k['SW (mmHg*µL)'], bl1_rat_7k['SW (mmHg*µL)'], 
                     bl2_rat_7k['SW (mmHg*µL)'], bls2_rat_7k['SW (mmHg*µL)'], bl4_rat_10k['SW (mmHg*µL)'], 
                     bls1_rat_10k['SW (mmHg*µL)']], axis=1, join='inner')

# %%
reshape
# Out:
#     SW (mmHg*µL)  SW (mmHg*µL)  SW (mmHg*µL)  SW (mmHg*µL)  SW (mmHg*µL)  \
# 0     35110000.0    31060000.0    37400000.0    57260000.0    26850000.0
# 1     32880000.0    61040000.0    39750000.0    34630000.0    36530000.0
# 2     32080000.0    41040000.0    42070000.0    56770000.0    38580000.0
# 3     33040000.0    35430000.0    37860000.0    39390000.0    29940000.0
# 4     30970000.0    53600000.0    38490000.0    47770000.0    32130000.0
# 5     28800000.0    39140000.0    41840000.0    59980000.0    36540000.0
# 6     33520000.0    57170000.0    40900000.0    37490000.0    31920000.0
# 7     30480000.0    41370000.0    37090000.0    41320000.0    29070000.0
# 8     29390000.0    31800000.0    40610000.0    57890000.0    34500000.0
# 9     27990000.0    50010000.0    41940000.0    30280000.0    35290000.0
# 10    32970000.0    40860000.0    38450000.0    53580000.0    27200000.0
# 11    30030000.0    34950000.0    37880000.0    53310000.0    32270000.0
# ...

# %%
reshape = reshape.as_matrix(columns=None)
plt.boxplot(x = reshape)
# plt.boxplot(x= (bl1_rat_6k['SW (mmHg*µL)'], bls_rat_6k['SW (mmHg*µL)'], bl1_rat_7k['SW (mmHg*µL)']).values.reshape())
# plt.boxplot(x=bls_rat_6k['SW (mmHg*µL)'])
plt.title('all baselines control', color='green')
plt.ylabel('SW')
plt.show()

# %%
plt.figure(figsize=(8,8))
reshape = pd.concat([bl2_rat_13['SW (mmHg*µL)'], bls2_rat_13['SW (mmHg*µL)'], bl_rat_15['SW (mmHg*µL)'], 
                     bls_rat_15['SW (mmHg*µL)'], bl4r_rat_16['SW (mmHg*µL)'], bls2r_rat_16['SW (mmHg*µL)']], 
                    axis=1, join='inner')
reshape = reshape.as_matrix(columns=None)
plt.boxplot(x = reshape)
plt.title('all baselines dox', color='green')
plt.ylabel('SW')
plt.show()

# %%
# plt.figure(figsize=(8,8))
fig, axs = plt.subplots(1, 2)

reshape = pd.concat([bl1_rat_6k['SW (mmHg*µL)'], bls_rat_6k['SW (mmHg*µL)'], bl1_rat_7k['SW (mmHg*µL)'], 
                     bl2_rat_7k['SW (mmHg*µL)'], bls2_rat_7k['SW (mmHg*µL)'], bl4_rat_10k['SW (mmHg*µL)'], 
                     bls1_rat_10k['SW (mmHg*µL)']], axis=1, join='inner')
reshape = reshape.as_matrix(columns=None)
axs[0, 0].boxplot(x = reshape)
# plt.boxplot(x= (bl1_rat_6k['SW (mmHg*µL)'], bls_rat_6k['SW (mmHg*µL)'], bl1_rat_7k['SW (mmHg*µL)']).values.reshape())
# plt.boxplot(x=bls_rat_6k['SW (mmHg*µL)'])
axs[0, 0].title('all baselines control', color='green')
axs[0, 0].ylabel('SW')

reshape1 = pd.concat([bl2_rat_13['SW (mmHg*µL)'], bls2_rat_13['SW (mmHg*µL)'], bl_rat_15['SW (mmHg*µL)'], 
                     bls_rat_15['SW (mmHg*µL)'], bl4r_rat_16['SW (mmHg*µL)'], bls2r_rat_16['SW (mmHg*µL)']], 
                  axis=1, join='inner')
reshape1 = reshape1.as_matrix(columns=None)
axs[0, 1].boxplot(x = reshape1)
axs[0, 1].title('all baselines dox', color='green')
axs[0, 1].ylabel('SW')

# reshape2 = pd.concat([['SW (mmHg*µL)'], ['SW (mmHg*µL)'], ['SW (mmHg*µL)'], 
#                      ['SW (mmHg*µL)'], ['SW (mmHg*µL)'], ['SW (mmHg*µL)'], 
#                      ['SW (mmHg*µL)']], axis=1, join='inner')
# reshape2 = reshape2.as_matrix(columns=None)
# axs[0, 2].boxplot(x = reshape2)
# axs[0, 2].title('all baselines dox+skq', color='green')
# axs[0, 2].ylabel('SW')

# # fig.subplots_adjust(left=0.08, right=0.98, bottom=0.05, top=0.9,
# #                     hspace=0.4, wspace=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-19c77910eda6> in <module>()
#       6                      bls1_rat_10k['SW (mmHg*µL)']], axis=1, join='inner')
#       7 reshape = reshape.as_matrix(columns=None)
# ----> 8 axs[0, 0].boxplot(x = reshape)
#       9 # plt.boxplot(x= (bl1_rat_6k['SW (mmHg*µL)'], bls_rat_6k['SW (mmHg*µL)'], bl1_rat_7k['SW (mmHg*µL)']).values.reshape())
#      10 # plt.boxplot(x=bls_rat_6k['SW (mmHg*µL)'])
#
# IndexError: too many indices for array

# %%
plt.figure(figsize=(5,5))
reshape = pd.concat([bl1_rat_6k['SW (mmHg*µL)'], bl1_rat_7k['SW (mmHg*µL)'], 
                     bl2_rat_7k['SW (mmHg*µL)'], bl4_rat_10k['SW (mmHg*µL)']], axis=1, join='inner')
reshape = reshape.as_matrix(columns=None)
plt.boxplot(x = reshape)
# plt.boxplot(x= (bl1_rat_6k['SW (mmHg*µL)'], bls_rat_6k['SW (mmHg*µL)'], bl1_rat_7k['SW (mmHg*µL)']).values.reshape())
# plt.boxplot(x=bls_rat_6k['SW (mmHg*µL)'])
plt.title('baselines control', color='green')
plt.ylabel('SW')
plt.show()

# %%
plt.figure(figsize=(8,8))
reshape = pd.concat([bl2_rat_13['SW (mmHg*µL)'], bl_rat_15['SW (mmHg*µL)'], bl4r_rat_16['SW (mmHg*µL)']], 
                    axis=1, join='inner')
reshape = reshape.as_matrix(columns=None)
plt.boxplot(x = reshape)
plt.title('baselines dox', color='green')
plt.ylabel('SW')
plt.show()

# %%
plt.figure(figsize=(6,5))
reshape = pd.concat([bls_rat_6k['SW (mmHg*µL)'], bls2_rat_7k['SW (mmHg*µL)'], bls1_rat_10k['SW (mmHg*µL)']], axis=1, join='inner')
reshape = reshape.as_matrix(columns=None)
plt.boxplot(x = reshape)
# plt.boxplot(x= (bl1_rat_6k['SW (mmHg*µL)'], bls_rat_6k['SW (mmHg*µL)'], bl1_rat_7k['SW (mmHg*µL)']).values.reshape())
# plt.boxplot(x=bls_rat_6k['SW (mmHg*µL)'])
plt.title('baselines saline control', color='green')
plt.ylabel('SW')
plt.show()

# %%
plt.figure(figsize=(8,8))
reshape = pd.concat([bls2_rat_13['SW (mmHg*µL)'], bls_rat_15['SW (mmHg*µL)'], bls2r_rat_16['SW (mmHg*µL)']], 
                    axis=1, join='inner')
reshape = reshape.as_matrix(columns=None)
plt.boxplot(x = reshape)
plt.title('baselines saline dox', color='green')
plt.ylabel('SW')
plt.show()

# %%
control_bl = pd.concat([bl1_rat_6k, bl1_rat_7k, bl2_rat_7k, bl4_rat_10k]).reset_index().drop('index', axis=1)
control_bls = pd.concat([bls_rat_6k, bls2_rat_7k, bls1_rat_10k]).reset_index().drop('index', axis=1)
# control_bl
print(control_bl.shape[0])
print(control_bls.shape[0])
# control_bl.head()
# control_bls.head()
# Out:
# 114
# 103
