# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
# path = r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_6k\rat_6k_baseline_1.csv'
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_6k\rat_6k_baseline_1.csv', engine='python', sep=';', index_col=0)
df.head()
# Out:
#   SW (mmHg*µL) CO (µL/min) SV (µL) Vmax (µL) Vmin (µL) Ves (µL) Ved (µL)  \
# 1
# 2
# 3   3,511e+004  1,094e+005   278,9     412,9     134,0    142,5    396,8
# 4   3,288e+004  9,993e+004   254,8     392,7     137,8    144,9    377,1
# 5   3,208e+004  9,713e+004   247,7     385,2     137,5    143,4    377,4
#
#   Pmax (mmHg) Pmin (mmHg) Pmean (mmHg)   ...    PowMax (mmHg*µL/s)  \
# 1                                        ...
# 2                                        ...
# 3       166,1       4,889        96,64   ...            2,607e+005
# 4       165,1       4,096        95,24   ...            2,819e+005
# 5       164,7       4,855        94,83   ...            4,299e+005
#
#   dP/dt max (mmHg/s) dP/dt min (mmHg/s) dV/dt max (µL/s) dV/dt min (µL/s)  \
# 1
# 2
# 3         1,180e+004              -4575       1,196e+004            -6203
# 4         1,181e+004              -4691       1,175e+004            -6198
# ...

# %%
df1 = df[34:].copy()
df = df[:34]
df
# Out:
#    SW (mmHg*µL) CO (µL/min) SV (µL) Vmax (µL) Vmin (µL) Ves (µL) Ved (µL)  \
# 1
# 2
# 3    3,511e+004  1,094e+005   278,9     412,9     134,0    142,5    396,8
# 4    3,288e+004  9,993e+004   254,8     392,7     137,8    144,9    377,1
# 5    3,208e+004  9,713e+004   247,7     385,2     137,5    143,4    377,4
# 6    3,304e+004  9,680e+004   248,5     376,5     128,1    135,6    360,9
# 7    3,097e+004  9,676e+004   245,1     373,1     127,9    134,6    366,8
# 8    2,880e+004  9,451e+004   241,0     373,4     132,4    137,2    353,2
# 9    3,352e+004  1,022e+005   262,4     387,2     124,9    129,8    378,5
# 10   3,048e+004  8,975e+004   228,9     350,4     121,5    127,2    344,8
# 11   2,939e+004  9,251e+004   235,9     354,9     119,0    124,1    348,7
# 12   2,799e+004  1,026e+005   261,6     386,7     125,1    130,6    347,5
# 13   3,297e+004  1,031e+005   264,7     392,5     127,8    130,7    389,8
# 14   3,003e+004  8,918e+004   228,9     341,7     112,8    116,0    338,8
# ...

# %%
df1 = df1[1:]
df1
# Out:
#       SW (mmHg*µL) CO (µL/min) SV (µL) Vmax (µL) Vmin (µL) Ves (µL) Ved (µL)  \
# Avg     3,037e+004  9,771e+004   250,2     370,5     120,3    125,9    354,2
# Min     2,626e+004  8,504e+004   216,9     324,1     107,3    112,7    317,1
# Max     3,535e+004  1,186e+005   304,5     430,2     137,8    144,9    430,2
# Count           30          30      30        30        30       30       30
#
#       Pmax (mmHg) Pmin (mmHg) Pmean (mmHg)   ...    PowMax (mmHg*µL/s)  \
# Avg         160,4       3,676        90,64   ...            2,945e+005
# Min         156,8       1,443        86,14   ...            1,708e+005
# Max         166,1       5,040        96,64   ...            4,299e+005
# Count          30          30           30   ...                    30
#
#       dP/dt max (mmHg/s) dP/dt min (mmHg/s) dV/dt max (µL/s) dV/dt min (µL/s)  \
# Avg           1,172e+004              -5152       1,014e+004            -6037
# ...

# %%
import locale
locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_6k\rat_6k_occlusion_3.csv', engine='python', sep=';', index_col=0)
df1 = df[17:].copy()
df = df[:17]
import locale
locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_6k'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
o_rat_6k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
o_rat_6k = o_rat_6k.drop(['Min', 'Max', 'Count'])
# o_rat_6k.max()
df.count()
# Out:
# SW (mmHg*µL)          17
# CO (µL/min)           17
# SV (µL)               17
# Vmax (µL)             17
# Vmin (µL)             17
# Ves (µL)              17
# Ved (µL)              17
# Pmax (mmHg)           17
# Pmin (mmHg)           17
# Pmean (mmHg)          17
# Pdev (mmHg)           17
# Pes (mmHg)            17
# Ped (mmHg)            17
# HR (bpm)              17
# EF (%)                17
# Ea (mmHg/µL)          17
# PowMax (mmHg*µL/s)    17
# dP/dt max (mmHg/s)    17
# dP/dt min (mmHg/s)    17
# dV/dt max (µL/s)      17
# dV/dt min (µL/s)      17
# P@dV/dt max (mmHg)    17
# P@dP/dt max (mmHg)    17
# V@dP/dt max (µL)      17
# V@dP/dt min (µL)      17
# PVA (mmHg*µL)         17
# PE (mmHg*µL)          17
# CE                    17
# Tau (ms)              17
# dtype: int64

# %%
# df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_6k\rat_6k_occlusion_saline.csv', engine='python', sep=';', index_col=0)
# df1 = df[16:].copy()
# df = df[:16]
# # import locale
# # locale.setlocale(locale.LC_NUMERIC, '')
# df1 = df1.applymap(locale.atof)
# df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
# df1.rename(index={'Avg': 'rat_6k'}, inplace=True)
# # df1.rename_axis('rat',  append=True)
# df1.index.name = 'rat'
# os_rat_6k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
#                              'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
#                             'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
# os_rat_6k = os_rat_6k.drop(['Min', 'Max', 'Count'])

# %%
# df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_6k\rat_6k_occlusion_saline_1.csv', engine='python', sep=';', index_col=0)
# df1 = df[17:].copy()
# df = df[:17]
# df1 = df1[1:]
# df1
# # import locale
# # locale.setlocale(locale.LC_NUMERIC, '')
# df1 = df1.applymap(locale.atof)
# df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
# df1.rename(index={'Avg': 'rat_6k'}, inplace=True)
# # df1.rename_axis('rat',  append=True)
# df1.index.name = 'rat'
# os1_rat_6k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
#                              'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
#                             'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
# os1_rat_6k = os1_rat_6k.drop(['Min', 'Max', 'Count'])

# %%
df = df.drop(df.index[[0, 1, 15, 16]]).applymap(locale.atof).reset_index(drop=True)
df.tail()
# Out:
#     SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# 25    35350000.0  105600000.0   2729.0     3925.0     1197.0    1276.0
# 26    29310000.0   89190000.0   2274.0     3365.0     1091.0    1147.0
# 27    28630000.0   87280000.0   2240.0     3351.0     1111.0    1165.0
# 28    28430000.0   93760000.0   2406.0     3600.0     1194.0    1241.0
# 29    31690000.0   98220000.0   2521.0     3634.0     1113.0    1171.0
#
#     Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# 25    3873.0       1594.0       4287.0        8937.0    ...
# 26    3355.0       1607.0       4376.0        9157.0    ...
# 27    3300.0       1601.0       3426.0        9012.0    ...
# 28    3383.0       1584.0       2489.0        8857.0    ...
# 29    3623.0       1578.0       3911.0        8803.0    ...
#
#     PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# 25         316100000.0          11700000.0             -5135.0
# ...

# %%
df.max()
# Out:
# SW (mmHg*µL)           35350000.0
# CO (µL/min)           118600000.0
# SV (µL)                    3045.0
# Vmax (µL)                  4302.0
# Vmin (µL)                  1378.0
# Ves (µL)                   1449.0
# Ved (µL)                   4302.0
# Pmax (mmHg)                1661.0
# Pmin (mmHg)                5040.0
# Pmean (mmHg)               9664.0
# Pdev (mmHg)                1612.0
# Pes (mmHg)                 1537.0
# Ped (mmHg)                 9218.0
# HR (bpm)                   3947.0
# EF (%)                     9463.0
# Ea (mmHg/µL)               6837.0
# PowMax (mmHg*µL/s)    429900000.0
# dP/dt max (mmHg/s)     11860000.0
# dP/dt min (mmHg/s)        -4575.0
# dV/dt max (µL/s)       12840000.0
# dV/dt min (µL/s)          -5159.0
# P@dV/dt max (mmHg)         6770.0
# P@dP/dt max (mmHg)         9955.0
# V@dP/dt max (µL)           3695.0
# V@dP/dt min (µL)           1463.0
# Tau (ms)                   1478.0
# dtype: float64

# %%
df1
# Out:
#        SW (mmHg*µL)  CO (µL/min)  SV (µL)  Vmax (µL)  Vmin (µL)  Ves (µL)  \
# Avg      30370000.0   97710000.0   2502.0     3705.0     1203.0    1259.0
# Min      26260000.0   85040000.0   2169.0     3241.0     1073.0    1127.0
# Max      35350000.0  118600000.0   3045.0     4302.0     1378.0    1449.0
# Count          30.0         30.0     30.0       30.0       30.0      30.0
#
#        Ved (µL)  Pmax (mmHg)  Pmin (mmHg)  Pmean (mmHg)    ...     \
# Avg      3542.0       1604.0       3676.0        9064.0    ...
# Min      3171.0       1568.0       1443.0        8614.0    ...
# Max      4302.0       1661.0       5040.0        9664.0    ...
# Count      30.0         30.0         30.0          30.0    ...
#
#        PowMax (mmHg*µL/s)  dP/dt max (mmHg/s)  dP/dt min (mmHg/s)  \
# Avg           294500000.0          11720000.0             -5152.0
# Min           170800000.0          11600000.0             -5922.0
# Max           429900000.0          11860000.0             -4575.0
# ...

# %%
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_6k'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'

# %%
bl_rat_6k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)

# %%
bl_rat_6k = bl_rat_6k.drop(['Min', 'Max', 'Count'])
bl_rat_6k['type1'] = ('control')
bl_rat_6k['type2'] = ('baseline')
bl_rat_6k
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_6k    30370000.0   97710000.0   2502.0    1259.0    3542.0      1494.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_6k      6769.0    3905.0  7574.0        6015.0         294500000.0
#
#         dP/dt max (mmHg/s)     IVG (1/s)    type1     type2
# rat
# rat_6k          11720000.0  11236.816874  control  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_7k\rat_7k_baseline_1.csv', engine='python', sep=';', index_col=0)
df1 = df[26:].copy()
df = df[:26]
df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_7k'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bl1_rat_7k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bl1_rat_7k = bl1_rat_7k.drop(['Min', 'Max', 'Count'])
bl1_rat_7k['type1'] = ('control')
bl1_rat_7k['type2'] = ('baseline')
bl1_rat_7k
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_7k    39720000.0  123400000.0   3403.0    1670.0    4901.0      1365.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_7k      2739.0    3625.0  7208.0        4014.0         117200000.0
#
#         dP/dt max (mmHg/s)    IVG (1/s)    type1     type2
# rat
# rat_7k          10860000.0  1116.709512  control  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_6k\rat_6k_baseline_saline.csv', engine='python', sep=';', index_col=0)
df.head()
df1 = df[32:].copy()
df = df[:32]
import locale
locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_6k'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bls_rat_6k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bls_rat_6k = bls_rat_6k.drop(['Min', 'Max', 'Count'])
bls_rat_6k['type1'] = ('control')
bls_rat_6k['type2'] = ('baseline saline')
bls_rat_6k
rat_6k = pd.concat([bl_rat_6k, bls_rat_6k])

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_7k\rat_7k_baseline_2.csv', engine='python', sep=';', index_col=0)
df1 = df[25:].copy()
df = df[:25]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_7k'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bl2_rat_7k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bl2_rat_7k = bl2_rat_7k.drop(['Min', 'Max', 'Count'])
bl2_rat_7k['type1'] = ('control')
bl2_rat_7k['type2'] = ('baseline')
bl2_rat_7k
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_7k    45590000.0  147200000.0   3912.0    1648.0    5049.0      1491.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_7k      2909.0    3765.0  7852.0        3859.0         296800000.0
#
#         dP/dt max (mmHg/s)     IVG (1/s)    type1     type2
# rat
# rat_7k          11770000.0  11230.916031  control  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_10k\rat_10k_baseline_4.csv', engine='python', sep=';', index_col=0)
df1 = df[36:].copy()
df = df[:36]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_10k'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bl4_rat_10k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bl4_rat_10k = bl4_rat_10k.drop(['Min', 'Max', 'Count'])
bl4_rat_10k['type1'] = ('control')
bl4_rat_10k['type2'] = ('baseline')
bl4_rat_10k
# Out:
#          SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_10k    37750000.0  130200000.0   3623.0    3114.0    6166.0      1182.0
#
#          Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_10k      1255.0    3592.0  5922.0        3336.0         262400000.0
#
#          dP/dt max (mmHg/s)    IVG (1/s)    type1     type2
# rat
# rat_10k          11510000.0  1288.336691  control  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_7k\rat_7k_baseline_saline_2.csv', engine='python', sep=';', index_col=0)
df1 = df[36:].copy()
df = df[:36]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_7k'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bls2_rat_7k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bls2_rat_7k = bls2_rat_7k.drop(['Min', 'Max', 'Count'])
bls2_rat_7k['type1'] = ('control')
bls2_rat_7k['type2'] = ('baseline saline')
bls2_rat_7k
rat_7k = pd.concat([bls2_rat_7k, bl2_rat_7k, bl1_rat_7k])

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Control\rat_10k\rat_10k_baseline_saline_1.csv', engine='python', sep=';', index_col=0)
df1 = df[38:].copy()
df = df[:38]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_10k'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bls1_rat_10k = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bls1_rat_10k = bls1_rat_10k.drop(['Min', 'Max', 'Count'])
bls1_rat_10k['type1'] = ('control')
bls1_rat_10k['type2'] = ('baseline saline')
bls1_rat_10k
rat_10k = pd.concat([bl4_rat_10k, bls1_rat_10k])

# %%
control = pd.concat([rat_10k, rat_7k, rat_6k])
control
# Out:
#          SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_10k    37750000.0  130200000.0   3623.0    3114.0    6166.0      1182.0
# rat_10k    27180000.0   91440000.0   2445.0    2716.0    4861.0      1283.0
# rat_7k     32820000.0  100900000.0   2807.0    1903.0    4463.0      1397.0
# rat_7k     45590000.0  147200000.0   3912.0    1648.0    5049.0      1491.0
# rat_7k     39720000.0  123400000.0   3403.0    1670.0    4901.0      1365.0
# rat_6k     30370000.0   97710000.0   2502.0    1259.0    3542.0      1494.0
# rat_6k     43010000.0  183200000.0   4569.0    2174.0    6181.0      1425.0
#
#          Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_10k      1255.0    3592.0  5922.0        3336.0         262400000.0
# rat_10k      1014.0    3739.0  5150.0        5317.0         223000000.0
# rat_7k       2451.0    3595.0  6312.0        4982.0         238900000.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_13\rat_13_baseline_2.csv', engine='python', sep=';', index_col=0)
df1 = df[32:].copy()
df = df[:32]
df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_13'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bl2_rat_13 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bl2_rat_13 = bl2_rat_13.drop(['Min', 'Max', 'Count'])
bl2_rat_13['type1'] = ('dox')
bl2_rat_13['type2'] = ('baseline')
bl2_rat_13
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_13        4992.0   39920000.0   2126.0    8716.0    1162.0      4820.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_13      1712.0    1878.0  1455.0        2312.0         259700000.0
#
#         dP/dt max (mmHg/s)  IVG (1/s) type1     type2
# rat
# rat_13              1856.0   0.588273   dox  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_15\rat_15_baseline.csv', engine='python', sep=';', index_col=0)
df1 = df[13:].copy()
df = df[:13]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_15'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bl_rat_15 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bl_rat_15 = bl_rat_15.drop(['Min', 'Max', 'Count'])
bl_rat_15['type1'] = ('dox')
bl_rat_15['type2'] = ('baseline')
bl_rat_15
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_15    31580000.0   92910000.0   2892.0    3658.0    5856.0      1269.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_15      9479.0    3209.0  4523.0        4420.0         202000000.0
#
#         dP/dt max (mmHg/s)  IVG (1/s) type1     type2
# rat
# rat_15              7548.0    0.89697   dox  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_16\rat_16_baseline_4_revsion.csv', engine='python', sep=';', index_col=0)
df1 = df[19:].copy()
df = df[:19]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_16'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bl4r_rat_16 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bl4r_rat_16 = bl4r_rat_16.drop(['Min', 'Max', 'Count'])
bl4r_rat_16['type1'] = ('dox')
bl4r_rat_16['type2'] = ('baseline')
bl4r_rat_16
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_16    39430000.0  103400000.0   4120.0    3104.0    6182.0      8160.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_16     -3375.0    2511.0  6138.0        2049.0         157000000.0
#
#         dP/dt max (mmHg/s)  IVG (1/s) type1     type2
# rat
# rat_16              4424.0   1.227866   dox  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_13\rat_13_baseline_saline_2.csv', engine='python', sep=';', index_col=0)
df1 = df[7:].copy()
df = df[:7]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_13'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bls2_rat_13 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bls2_rat_13 = bls2_rat_13.drop(['Min', 'Max', 'Count'])
bls2_rat_13['type1'] = ('dox')
bls2_rat_13['type2'] = ('baseline saline')
bls2_rat_13
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_13    15220000.0   79380000.0   4249.0    2442.0    3680.0      5037.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_13      8831.0    1868.0  8959.0        1186.0         421400000.0
#
#         dP/dt max (mmHg/s)  IVG (1/s) type1            type2
# rat
# rat_13              1859.0   0.548216   dox  baseline saline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_15\rat_15_baseline_saline.csv', engine='python', sep=';', index_col=0)
df1 = df[22:].copy()
df = df[:22]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_15'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bls_rat_15 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bls_rat_15 = bls_rat_15.drop(['Min', 'Max', 'Count'])
bls_rat_15['type1'] = ('dox')
bls_rat_15['type2'] = ('baseline saline')
bls_rat_15
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_15    32470000.0   94680000.0   2980.0    4347.0    5428.0      1279.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_15      4409.0    3178.0  4174.0        4296.0         118400000.0
#
#         dP/dt max (mmHg/s)  IVG (1/s) type1            type2
# rat
# rat_15              7393.0   0.861153   dox  baseline saline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox\rat_16\rat_16_baseline_saline_2_revsion.csv', engine='python', sep=';', index_col=0)
df1 = df[10:].copy()
df = df[:10]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_16'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bls2r_rat_16 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bls2r_rat_16 = bls2r_rat_16.drop(['Min', 'Max', 'Count'])
bls2r_rat_16['type1'] = ('dox')
bls2r_rat_16['type2'] = ('baseline saline')
bls2r_rat_16
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_16    32190000.0  124700000.0   5137.0    1419.0    5276.0      7186.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_16     -2113.0    2427.0  8430.0        1439.0          84230000.0
#
#         dP/dt max (mmHg/s)  IVG (1/s) type1            type2
# rat
# rat_16              2507.0   0.545593   dox  baseline saline

# %%
dox = pd.concat([bls2r_rat_16, bl4r_rat_16, bls_rat_15, bl_rat_15, bls2_rat_13, bl2_rat_13, ])
dox
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_16    32190000.0  124700000.0   5137.0    1419.0    5276.0      7186.0
# rat_16    39430000.0  103400000.0   4120.0    3104.0    6182.0      8160.0
# rat_15    32470000.0   94680000.0   2980.0    4347.0    5428.0      1279.0
# rat_15    31580000.0   92910000.0   2892.0    3658.0    5856.0      1269.0
# rat_13    15220000.0   79380000.0   4249.0    2442.0    3680.0      5037.0
# rat_13        4992.0   39920000.0   2126.0    8716.0    1162.0      4820.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_16     -2113.0    2427.0  8430.0        1439.0          84230000.0
# rat_16     -3375.0    2511.0  6138.0        2049.0         157000000.0
# rat_15      4409.0    3178.0  4174.0        4296.0         118400000.0
# rat_15      9479.0    3209.0  4523.0        4420.0         202000000.0
# rat_13      8831.0    1868.0  8959.0        1186.0         421400000.0
# ...

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox+Skq\rat_31\rat_31_baseline_3.csv', engine='python', sep=';', index_col=0)
df1 = df[23:].copy()
df = df[:23]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_31'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bl3_rat_31 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bl3_rat_31 = bl3_rat_31.drop(['Min', 'Max', 'Count'])
bl3_rat_31['type1'] = ('dox + skq')
bl3_rat_31['type2'] = ('baseline')
bl3_rat_31
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_31    26630000.0   82260000.0   2024.0    1318.0    2829.0      1507.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_31      1250.0    4064.0  6176.0        7459.0         131900000.0
#
#         dP/dt max (mmHg/s)     IVG (1/s)      type1     type2
# rat
# rat_31          13000000.0  12195.121951  dox + skq  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox+Skq\rat_34\rat_34_baseline_2_no_ivl.csv', engine='python', sep=';', index_col=0)
df1 = df[15:].copy()
df = df[:15]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_34'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bl2ni_rat_34 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bl2ni_rat_34 = bl2ni_rat_34.drop(['Min', 'Max', 'Count'])
bl2ni_rat_34['type1'] = ('dox + skq')
bl2ni_rat_34['type2'] = ('baseline')
bl2ni_rat_34
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_34    41590000.0  131300000.0   3709.0    1186.0    3926.0      1416.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_34      8646.0    3541.0  8442.0        3826.0         796800000.0
#
#         dP/dt max (mmHg/s)     IVG (1/s)      type1     type2
# rat
# rat_34          10780000.0  10486.381323  dox + skq  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox+Skq\rat_36\rat_36_baseline_2.csv', engine='python', sep=';', index_col=0)
df1 = df[19:].copy()
df = df[:19]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_36'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bl2_rat_36 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bl2_rat_36 = bl2_rat_36.drop(['Min', 'Max', 'Count'])
bl2_rat_36['type1'] = ('dox + skq')
bl2_rat_36['type2'] = ('baseline')
bl2_rat_36
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_36    23230000.0   82590000.0   1877.0    1822.0    3202.0      1313.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_36      5047.0    4399.0  5146.0        7058.0          95630000.0
#
#         dP/dt max (mmHg/s)    IVG (1/s)      type1     type2
# rat
# rat_36          11280000.0  1209.910973  dox + skq  baseline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox+Skq\rat_31\rat_31_baseline_saline.csv', engine='python', sep=';', index_col=0)
df1 = df[21:].copy()
df = df[:21]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_31'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bls_rat_31 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bls_rat_31 = bls_rat_31.drop(['Min', 'Max', 'Count'])
bls_rat_31['type1'] = ('dox + skq')
bls_rat_31['type2'] = ('baseline saline')
bls_rat_31
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_31    25230000.0   77180000.0   1924.0    1599.0    3147.0      1491.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_31      1333.0    4012.0  5570.0        7777.0         110600000.0
#
#         dP/dt max (mmHg/s)     IVG (1/s)      type1            type2
# rat
# rat_31          13180000.0  12306.255836  dox + skq  baseline saline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox+Skq\rat_34\rat_34_baseline_saline_2.csv', engine='python', sep=';', index_col=0)
df1 = df[36:].copy()
df = df[:36]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_34'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bls2_rat_34 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bls2_rat_34 = bls2_rat_34.drop(['Min', 'Max', 'Count'])
bls2_rat_34['type1'] = ('dox + skq')
bls2_rat_34['type2'] = ('baseline saline')
bls2_rat_34
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_34    45590000.0  150000000.0   4782.0    2273.0    5478.0      1207.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_34      8868.0    3137.0  7713.0        2578.0         882900000.0
#
#         dP/dt max (mmHg/s)  IVG (1/s)      type1            type2
# rat
# rat_34              7411.0   0.863552  dox + skq  baseline saline

# %%
df = pd.read_csv(r'C:\Users\Елена\Python\pvloop\data\Lena\Dox+Skq\rat_36\rat_36_baseline_saline_2.csv', engine='python', sep=';', index_col=0)
df1 = df[21:].copy()
df = df[:21]
# df1
# df1 = df1[1:]
# df1
# import locale
# locale.setlocale(locale.LC_NUMERIC, '')
df1 = df1.applymap(locale.atof)
df1['IVG (1/s)'] = df1['dP/dt max (mmHg/s)']/df1['P@dP/dt max (mmHg)']
df1.rename(index={'Avg': 'rat_36'}, inplace=True)
# df1.rename_axis('rat',  append=True)
df1.index.name = 'rat'
bls2_rat_36 = df1.copy().drop(['Vmax (µL)', 'Vmin (µL)', 'Pmax (mmHg)', 'Pmin (mmHg)', 'Pmean (mmHg)', 'Pdev (mmHg)', 
                             'dP/dt min (mmHg/s)', 'dV/dt max (µL/s)', 'dV/dt min (µL/s)', 'P@dV/dt max (mmHg)', 
                            'P@dP/dt max (mmHg)', 'V@dP/dt max (µL)', 'V@dP/dt min (µL)', 'Tau (ms)'], axis=1)
bls2_rat_36 = bls2_rat_36.drop(['Min', 'Max', 'Count'])
bls2_rat_36['type1'] = ('dox + skq')
bls2_rat_36['type2'] = ('baseline saline')
bls2_rat_36
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_36    21290000.0   78150000.0   1792.0    1942.0    3343.0      1272.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_36      6428.0    4361.0  4893.0        7163.0          95230000.0
#
#         dP/dt max (mmHg/s)    IVG (1/s)      type1            type2
# rat
# rat_36          10940000.0  1162.592986  dox + skq  baseline saline

# %%
dox_skq = pd.concat([bl3_rat_31, bls_rat_31, bl2ni_rat_34, bls2_rat_34, bl2_rat_36, bls2_rat_36])
dox_skq
# Out:
#         SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_31    26630000.0   82260000.0   2024.0    1318.0    2829.0      1507.0
# rat_31    25230000.0   77180000.0   1924.0    1599.0    3147.0      1491.0
# rat_34    41590000.0  131300000.0   3709.0    1186.0    3926.0      1416.0
# rat_34    45590000.0  150000000.0   4782.0    2273.0    5478.0      1207.0
# rat_36    23230000.0   82590000.0   1877.0    1822.0    3202.0      1313.0
# rat_36    21290000.0   78150000.0   1792.0    1942.0    3343.0      1272.0
#
#         Ped (mmHg)  HR (bpm)  EF (%)  Ea (mmHg/µL)  PowMax (mmHg*µL/s)  \
# rat
# rat_31      1250.0    4064.0  6176.0        7459.0         131900000.0
# rat_31      1333.0    4012.0  5570.0        7777.0         110600000.0
# rat_34      8646.0    3541.0  8442.0        3826.0         796800000.0
# rat_34      8868.0    3137.0  7713.0        2578.0         882900000.0
# rat_36      5047.0    4399.0  5146.0        7058.0          95630000.0
# ...

# %%
baselines = pd.concat([control, dox, dox_skq])
baselines
# Out:
#          SW (mmHg*µL)  CO (µL/min)  SV (µL)  Ves (µL)  Ved (µL)  Pes (mmHg)  \
# rat
# rat_10k    37750000.0  130200000.0   3623.0    3114.0    6166.0      1182.0
# rat_10k    27180000.0   91440000.0   2445.0    2716.0    4861.0      1283.0
# rat_7k     32820000.0  100900000.0   2807.0    1903.0    4463.0      1397.0
# rat_7k     45590000.0  147200000.0   3912.0    1648.0    5049.0      1491.0
# rat_7k     39720000.0  123400000.0   3403.0    1670.0    4901.0      1365.0
# rat_6k     30370000.0   97710000.0   2502.0    1259.0    3542.0      1494.0
# rat_6k     43010000.0  183200000.0   4569.0    2174.0    6181.0      1425.0
# rat_16     32190000.0  124700000.0   5137.0    1419.0    5276.0      7186.0
# rat_16     39430000.0  103400000.0   4120.0    3104.0    6182.0      8160.0
# rat_15     32470000.0   94680000.0   2980.0    4347.0    5428.0      1279.0
# rat_15     31580000.0   92910000.0   2892.0    3658.0    5856.0      1269.0
# ...

# %%
# baselines.reset_index(level=['rat'])

# %%
# baselines.groupby(['type1', 'type2'])
# baselines.pivot_table(index='type1', columns='type2')
baselines.reset_index().set_index(['type1', 'rat', 'type2'])
# Out:
#                                    SW (mmHg*µL)  CO (µL/min)  SV (µL)  \
# type1     rat     type2
# control   rat_10k baseline           37750000.0  130200000.0   3623.0
#                   baseline saline    27180000.0   91440000.0   2445.0
#           rat_7k  baseline saline    32820000.0  100900000.0   2807.0
#                   baseline           45590000.0  147200000.0   3912.0
#                   baseline           39720000.0  123400000.0   3403.0
#           rat_6k  baseline           30370000.0   97710000.0   2502.0
#                   baseline saline    43010000.0  183200000.0   4569.0
# dox       rat_16  baseline saline    32190000.0  124700000.0   5137.0
#                   baseline           39430000.0  103400000.0   4120.0
#           rat_15  baseline saline    32470000.0   94680000.0   2980.0
#                   baseline           31580000.0   92910000.0   2892.0
#           rat_13  baseline saline    15220000.0   79380000.0   4249.0
# ...

# %%
baselines.pivot_table(index='type1', columns='type2')
# Out:
#             CO (µL/min)                       EF (%)                  \
# type2          baseline baseline saline     baseline baseline saline
# type1
# control    1.246275e+08    1.251800e+08  7139.000000     6661.666667
# dox        7.874333e+07    9.958667e+07  4038.666667     7187.666667
# dox + skq  9.871667e+07    1.017767e+08  6588.000000     6058.666667
#
#           Ea (mmHg/µL)                     HR (bpm)                  \
# type2         baseline baseline saline     baseline baseline saline
# type1
# control    4306.000000     4490.000000  3721.750000     3781.333333
# dox        2927.000000     2307.000000  2532.666667     2491.000000
# dox + skq  6114.333333     5839.333333  4001.333333     3836.666667
#
#              IVG (1/s)                       ...            SV (µL)  \
# type2         baseline baseline saline       ...           baseline
# type1                                        ...
# control    6218.194777     4427.434352       ...        3360.000000
# ...
